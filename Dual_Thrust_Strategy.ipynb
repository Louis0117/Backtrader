# %% [markdown]
# # Dual Thrust Strategy
# -----
#
# * buying signal (long): current price > cap
# * selling signal (short): current price < floor
# * k1, k2 are pyperparameters / Range can be calculated
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Range calculation
#
# #####
# <center>$Range = max(HH-LC, HC-LL)$</center>
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### K1, K2 adjust logic
#
# * Bullish : K1 smaller, k2 larger
# * Bearllish : k1 larger, k2 smaller
